# %%
"""This module is used to generate plotly figures for stock rollover and sales figures over the whole year.
Jurisdiction: SCAG
Time period: 2000 - 2050 ## TODO: Verify
Applications of interest: 
    1) Vehicles - HDV, MDV, LDV, Buses
    2) Space Heating - Res, Com
    3) Water Heating - Res, Com
    TODO: Update menus to include axis labels
    TODO: Update color shemes
    TODO: Update slider options (Reference case first)
    TODO: All the remaining TODOs 
"""
import pandas as pd
import numpy as np
import os

import plotly.offline as pyo
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *
from plotly import tools

from scag_colors import gen_color, scenario_colors, veh_fuel_colors
from ScagApp import ScagApp

pyo.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
def plot_graphs(name):
    application = ScagApp(name,'S:\E3 Projects\SCAG Pathways\PlotlyDev\PATHWAYS_csvs')
    print(application)
    pyo.iplot(application.stock_rollover_figure())
    if application.shares_present:
        pyo.iplot(application.shares_figure())

# %%
app_list = ['COM_AC', 'COM_LT', 'COM_SH', 'COM_WH', 'HDV', 'LDV', 'MDV', 'RES_CA', 'RES_HS', 'RES_LI', 'RES_SH', 'RES_WH']

plot_graphs('MDV')
# Out:
# Diesel Hybrid MDV
# Efficient MDV Diesel
# Efficient MDV Gasoline
# MDV Battery Electric
# MDV CNG
# MDV Hydrogen FCV
# Reference MDV-Diesel
# Reference MDV-Gasoline
#
# Application Name: MDV
# Scenarios :['2016 RTP/SCS', 'High Electrification', 'High Renewable Gas', 'Reference']
# Technologies: ['Diesel Hybrid MDV', 'Efficient MDV Diesel', 'Efficient MDV Gasoline', 'MDV Battery Electric', 'MDV CNG', 'MDV Hydrogen FCV', 'Reference MDV-Diesel', 'Reference MDV-Gasoline']
# Data found from 2010 to 2050
# ...
